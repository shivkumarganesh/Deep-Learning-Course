# %% [markdown]
# # Numpy to Build Neural Network

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.manifold import TSNE
from sklearn.metrics import mean_squared_error
import numpy as np
import torch

# %% [markdown]
# # Utility functions

# %%
def plot_3d(comp, graph_title, X, y, y_pred=None):
    X_tnse = TSNE(n_components=comp, random_state=123).fit_transform(X)
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(X_tnse[:,0], X_tnse[:,1], y, label='y_true')
    ax.set_title(graph_title)
    if y_pred is not None:
        ax.scatter(X_tnse[:,0], X_tnse[:,1], y_pred, label='y_pred', marker='v')
    plt.legend()
    plt.show()

# %% [markdown]
# # Generating Sample data 3 inputs & 2 output

# %%
n = 200

# We need to take 3 inputs
inputs_dimensions = 3

# We need to have 2 outputs
output_dimensions = 2

# Setup some random seed instead of np.random.seed(2232) use Torch
torch.manual_seed(2232)

# Generating X with 3 dimentions
X = torch.rand((n, inputs_dimensions)).uniform_(-1,1)
print('Sample Value for X:' + str(X[:3]))

# Generating the value of the y_true
weights_true = np.array([[4., 3., -2.],[-1., -1., 3.]])
bias_true = np.array([[1],[1]])

y_true = (9. * X ** 2.) @ weights_true.T + X @ weights_true.T + bias_true.T

print('Sample Value for y:'+ str(y_true[:3]))
# Out:
# Sample Value for X:tensor([[ 0.6869, -0.6098,  0.8382],
#         [ 0.2776, -0.7326,  0.4000],
#         [ 0.0560,  0.3198, -0.9075]])
# Sample Value for y:tensor([[14.6238, 14.8144],
#         [13.4994,  1.4501],
#         [-7.9519, 19.1902]], dtype=torch.float64)

# %% [markdown]
# # Plotting the data in a 3-Dimentional Plane

# %%
plot_3d(2, 'Output 1', X, y_true[:,0])
plot_3d(2, 'Output 2', X, y_true[:,1])

# %% [markdown]
# # Hyperparameters - Various Parameters that we will be using

# %%
# Number of Iterations
epochs = 200

# Learning rate of the algorithm
learning_rate = 0.01

# Inputs and outputs size. i.e 2 and 3 relatively
X_inputs = X.shape[1]
y_test_outputs = y_true.shape[1]

print(inputs)
print(outputs)
# Out:
# 3
# 2

# %%
# Inspired from https://towardsdatascience.com/how-to-code-a-simple-neural-network-in-pytorch-for-absolute-beginners-8f5209c50fdd
# Inheriting from nn. Module provides functionality to your component. 
# For example, it makes it keep track of its trainable parameters, 
# you can swap it between CPU and GPU with the .to(device) method, 
# where device can be a CPU device torch. device("cpu") or CUDA device torch.
# NOTE: Regression Tasks do not have an activation function so lets avoid it

class NNModel(torch.nn.Module):
    def __init__(self, inputs=3, outputs=2, hidden=[2], activation=None):
        super(NNModel, self).__init__()

        self.num_inputs = inputs
        self.num_hidden = hidden
        self.num_outputs = outputs

        layers_nodes = [self.num_inputs] + self.num_hidden + [self.num_outputs]
    
        layers = []
        for i in range(len(layers_nodes[:-1])):
            if i == len(layers_nodes[:-1]) - 1:
                layers.append(torch.nn.Linear(layers_nodes[i], layers_nodes[i + 1]))
            else:
                layers.append(torch.nn.Linear(layers_nodes[i], layers_nodes[i + 1]))
                if activation == 'relu':
                    layers.append(torch.nn.ReLU())

        self.layers = torch.nn.ModuleList(layers)

    # Fir the model by taking in the learning rate and epochs and then iterating over the data
    def fit(self, X, y_true, learningRate, epochs):
        loss_fn  = torch.nn.MSELoss()
        optimizer = torch.optim.SGD(self.parameters(), lr=learningRate)
        for epoch in range(epochs):
            optimizer.zero_grad()
            
            y_pred = self.forward_pass(X)
            error = loss_fn(y_pred.float(), y_true.float())
            print(error)
            error.backward()
            optimizer.step()

    # Forward pass layer by laryer in order to propogate the values
    def forward_pass(self, x):
        current_output = X
        for layer in self.layers:
            current_output = layer(current_output)
        return current_output

# %% [markdown]
# # Training Performed using RELU as Activation

# %% [markdown]
# ## Let's see the number of layers

# %%
neuralModel = NNModel(inputs=inputs, outputs=outputs, hidden=[3, 2],  activation='relu')
print('Neural Network Architecture:')
print(neuralModel.layers)
# Out:
# Neural Network Architecture:
# ModuleList(
#   (0): Linear(in_features=3, out_features=3, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=3, out_features=2, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=2, out_features=2, bias=True)
# )

# %%
for identifier, params in neuralModel.named_parameters():
  print(f"Layer: {identifier} | Size: {params.size()} | Values : {params[:2]} \n")

neuralModel.fit(X, y_true, learning_rate, epochs)

y_pred = neuralModel.forward_pass(X).detach().numpy()
err = mean_squared_error(y_true, y_pred)
print('Final Error: {}'.format(err))
# Out:
# Layer: layers.0.weight | Size: torch.Size([3, 3]) | Values : tensor([[-0.3693, -0.1685,  0.2800],
#         [ 0.0807,  0.5107,  0.4394]], grad_fn=<SliceBackward>)
#
# Layer: layers.0.bias | Size: torch.Size([3]) | Values : tensor([ 0.1906, -0.4024], grad_fn=<SliceBackward>)
#
# Layer: layers.2.weight | Size: torch.Size([2, 3]) | Values : tensor([[ 0.0739,  0.2167,  0.1767],
#         [ 0.1218, -0.1301,  0.2659]], grad_fn=<SliceBackward>)
#
# Layer: layers.2.bias | Size: torch.Size([2]) | Values : tensor([ 0.0723, -0.4725], grad_fn=<SliceBackward>)
#
# Layer: layers.4.weight | Size: torch.Size([2, 2]) | Values : tensor([[ 0.4348, -0.4114],
#         [-0.0841,  0.0022]], grad_fn=<SliceBackward>)
#
# Layer: layers.4.bias | Size: torch.Size([2]) | Values : tensor([0.0363, 0.3102], grad_fn=<SliceBackward>)
#
# tensor(265.7015, grad_fn=<MseLossBackward>)
# tensor(262.7129, grad_fn=<MseLossBackward>)
# tensor(259.6125, grad_fn=<MseLossBackward>)
# tensor(256.3230, grad_fn=<MseLossBackward>)
# tensor(252.7459, grad_fn=<MseLossBackward>)
# tensor(248.7506, grad_fn=<MseLossBackward>)
# tensor(244.1632, grad_fn=<MseLossBackward>)
# tensor(238.7504, grad_fn=<MseLossBackward>)
# tensor(232.1952, grad_fn=<MseLossBackward>)
# tensor(224.0706, grad_fn=<MseLossBackward>)
# tensor(213.8615, grad_fn=<MseLossBackward>)
# tensor(201.0177, grad_fn=<MseLossBackward>)
# tensor(185.5631, grad_fn=<MseLossBackward>)
# tensor(168.8986, grad_fn=<MseLossBackward>)
# tensor(154.5764, grad_fn=<MseLossBackward>)
# tensor(146.4124, grad_fn=<MseLossBackward>)
# tensor(143.8967, grad_fn=<MseLossBackward>)
# tensor(143.3944, grad_fn=<MseLossBackward>)
# tensor(143.1964, grad_fn=<MseLossBackward>)
# tensor(143.0538, grad_fn=<MseLossBackward>)
# tensor(142.9376, grad_fn=<MseLossBackward>)
# tensor(142.8393, grad_fn=<MseLossBackward>)
# tensor(142.7531, grad_fn=<MseLossBackward>)
# tensor(142.6774, grad_fn=<MseLossBackward>)
# tensor(142.6080, grad_fn=<MseLossBackward>)
# tensor(142.5403, grad_fn=<MseLossBackward>)
# tensor(142.4747, grad_fn=<MseLossBackward>)
# tensor(142.4105, grad_fn=<MseLossBackward>)
# tensor(142.3451, grad_fn=<MseLossBackward>)
# tensor(142.2747, grad_fn=<MseLossBackward>)
# tensor(142.2037, grad_fn=<MseLossBackward>)
# tensor(142.1329, grad_fn=<MseLossBackward>)
# tensor(142.0617, grad_fn=<MseLossBackward>)
# tensor(141.9896, grad_fn=<MseLossBackward>)
# tensor(141.9132, grad_fn=<MseLossBackward>)
# tensor(141.8310, grad_fn=<MseLossBackward>)
# tensor(141.7365, grad_fn=<MseLossBackward>)
# tensor(141.6288, grad_fn=<MseLossBackward>)
# tensor(141.5103, grad_fn=<MseLossBackward>)
# tensor(141.3871, grad_fn=<MseLossBackward>)
# tensor(141.2544, grad_fn=<MseLossBackward>)
# tensor(141.1155, grad_fn=<MseLossBackward>)
# tensor(140.9682, grad_fn=<MseLossBackward>)
# tensor(140.8057, grad_fn=<MseLossBackward>)
# tensor(140.6314, grad_fn=<MseLossBackward>)
# tensor(140.4529, grad_fn=<MseLossBackward>)
# tensor(140.2692, grad_fn=<MseLossBackward>)
# tensor(140.0732, grad_fn=<MseLossBackward>)
# tensor(139.8646, grad_fn=<MseLossBackward>)
# tensor(139.6512, grad_fn=<MseLossBackward>)
# tensor(139.4254, grad_fn=<MseLossBackward>)
# tensor(139.1843, grad_fn=<MseLossBackward>)
# tensor(138.9378, grad_fn=<MseLossBackward>)
# tensor(138.6832, grad_fn=<MseLossBackward>)
# tensor(138.4183, grad_fn=<MseLossBackward>)
# tensor(138.1399, grad_fn=<MseLossBackward>)
# tensor(137.8533, grad_fn=<MseLossBackward>)
# tensor(137.5482, grad_fn=<MseLossBackward>)
# tensor(137.2307, grad_fn=<MseLossBackward>)
# tensor(136.8984, grad_fn=<MseLossBackward>)
# tensor(136.5515, grad_fn=<MseLossBackward>)
# tensor(136.2006, grad_fn=<MseLossBackward>)
# tensor(135.8360, grad_fn=<MseLossBackward>)
# tensor(135.4597, grad_fn=<MseLossBackward>)
# tensor(135.0706, grad_fn=<MseLossBackward>)
# tensor(134.6661, grad_fn=<MseLossBackward>)
# tensor(134.2434, grad_fn=<MseLossBackward>)
# tensor(133.8055, grad_fn=<MseLossBackward>)
# tensor(133.3501, grad_fn=<MseLossBackward>)
# tensor(132.8763, grad_fn=<MseLossBackward>)
# tensor(132.3858, grad_fn=<MseLossBackward>)
# tensor(131.8789, grad_fn=<MseLossBackward>)
# tensor(131.3510, grad_fn=<MseLossBackward>)
# tensor(130.8033, grad_fn=<MseLossBackward>)
# tensor(130.2364, grad_fn=<MseLossBackward>)
# tensor(129.6493, grad_fn=<MseLossBackward>)
# tensor(129.0424, grad_fn=<MseLossBackward>)
# tensor(128.4167, grad_fn=<MseLossBackward>)
# tensor(127.7711, grad_fn=<MseLossBackward>)
# tensor(127.0667, grad_fn=<MseLossBackward>)
# tensor(126.2106, grad_fn=<MseLossBackward>)
# tensor(125.2135, grad_fn=<MseLossBackward>)
# tensor(123.9295, grad_fn=<MseLossBackward>)
# tensor(122.2349, grad_fn=<MseLossBackward>)
# tensor(120.3278, grad_fn=<MseLossBackward>)
# tensor(118.2235, grad_fn=<MseLossBackward>)
# tensor(116.0540, grad_fn=<MseLossBackward>)
# tensor(113.9919, grad_fn=<MseLossBackward>)
# tensor(112.0858, grad_fn=<MseLossBackward>)
# tensor(110.2362, grad_fn=<MseLossBackward>)
# tensor(108.3211, grad_fn=<MseLossBackward>)
# tensor(106.6575, grad_fn=<MseLossBackward>)
# tensor(105.0767, grad_fn=<MseLossBackward>)
# tensor(103.5088, grad_fn=<MseLossBackward>)
# tensor(102.0483, grad_fn=<MseLossBackward>)
# tensor(100.5725, grad_fn=<MseLossBackward>)
# tensor(99.1006, grad_fn=<MseLossBackward>)
# tensor(97.6476, grad_fn=<MseLossBackward>)
# tensor(96.3308, grad_fn=<MseLossBackward>)
# tensor(95.0281, grad_fn=<MseLossBackward>)
# tensor(93.7654, grad_fn=<MseLossBackward>)
# tensor(92.5581, grad_fn=<MseLossBackward>)
# tensor(91.3744, grad_fn=<MseLossBackward>)
# tensor(90.2262, grad_fn=<MseLossBackward>)
# tensor(89.1810, grad_fn=<MseLossBackward>)
# tensor(88.1716, grad_fn=<MseLossBackward>)
# tensor(87.1784, grad_fn=<MseLossBackward>)
# tensor(86.1965, grad_fn=<MseLossBackward>)
# tensor(85.2302, grad_fn=<MseLossBackward>)
# tensor(84.3039, grad_fn=<MseLossBackward>)
# tensor(83.4102, grad_fn=<MseLossBackward>)
# tensor(82.5480, grad_fn=<MseLossBackward>)
# tensor(81.7452, grad_fn=<MseLossBackward>)
# tensor(80.9879, grad_fn=<MseLossBackward>)
# tensor(80.2503, grad_fn=<MseLossBackward>)
# tensor(79.5593, grad_fn=<MseLossBackward>)
# tensor(78.9118, grad_fn=<MseLossBackward>)
# tensor(78.3083, grad_fn=<MseLossBackward>)
# tensor(77.7340, grad_fn=<MseLossBackward>)
# tensor(77.1978, grad_fn=<MseLossBackward>)
# tensor(76.6938, grad_fn=<MseLossBackward>)
# tensor(76.2129, grad_fn=<MseLossBackward>)
# tensor(75.7554, grad_fn=<MseLossBackward>)
# tensor(75.3605, grad_fn=<MseLossBackward>)
# tensor(75.0303, grad_fn=<MseLossBackward>)
# tensor(74.6906, grad_fn=<MseLossBackward>)
# tensor(74.3514, grad_fn=<MseLossBackward>)
# tensor(74.0215, grad_fn=<MseLossBackward>)
# tensor(73.7050, grad_fn=<MseLossBackward>)
# tensor(73.4006, grad_fn=<MseLossBackward>)
# tensor(73.1171, grad_fn=<MseLossBackward>)
# tensor(72.8486, grad_fn=<MseLossBackward>)
# tensor(72.5966, grad_fn=<MseLossBackward>)
# tensor(72.3619, grad_fn=<MseLossBackward>)
# tensor(72.1385, grad_fn=<MseLossBackward>)
# tensor(71.9275, grad_fn=<MseLossBackward>)
# tensor(71.7265, grad_fn=<MseLossBackward>)
# tensor(71.5416, grad_fn=<MseLossBackward>)
# tensor(71.3646, grad_fn=<MseLossBackward>)
# tensor(71.2067, grad_fn=<MseLossBackward>)
# tensor(71.0632, grad_fn=<MseLossBackward>)
# tensor(70.9424, grad_fn=<MseLossBackward>)
# tensor(70.8113, grad_fn=<MseLossBackward>)
# tensor(70.6902, grad_fn=<MseLossBackward>)
# tensor(70.5560, grad_fn=<MseLossBackward>)
# tensor(70.4376, grad_fn=<MseLossBackward>)
# tensor(70.3062, grad_fn=<MseLossBackward>)
# tensor(70.1908, grad_fn=<MseLossBackward>)
# tensor(70.0682, grad_fn=<MseLossBackward>)
# tensor(69.9592, grad_fn=<MseLossBackward>)
# tensor(69.8375, grad_fn=<MseLossBackward>)
# tensor(69.7195, grad_fn=<MseLossBackward>)
# tensor(69.6049, grad_fn=<MseLossBackward>)
# tensor(69.4939, grad_fn=<MseLossBackward>)
# tensor(69.3803, grad_fn=<MseLossBackward>)
# tensor(69.2748, grad_fn=<MseLossBackward>)
# tensor(69.1697, grad_fn=<MseLossBackward>)
# tensor(69.0663, grad_fn=<MseLossBackward>)
# tensor(68.9542, grad_fn=<MseLossBackward>)
# tensor(68.8511, grad_fn=<MseLossBackward>)
# tensor(68.7415, grad_fn=<MseLossBackward>)
# tensor(68.6374, grad_fn=<MseLossBackward>)
# tensor(68.5317, grad_fn=<MseLossBackward>)
# tensor(68.4287, grad_fn=<MseLossBackward>)
# tensor(68.3288, grad_fn=<MseLossBackward>)
# tensor(68.2318, grad_fn=<MseLossBackward>)
# tensor(68.1321, grad_fn=<MseLossBackward>)
# tensor(68.0359, grad_fn=<MseLossBackward>)
# tensor(67.9367, grad_fn=<MseLossBackward>)
# tensor(67.8359, grad_fn=<MseLossBackward>)
# tensor(67.7332, grad_fn=<MseLossBackward>)
# tensor(67.6326, grad_fn=<MseLossBackward>)
# tensor(67.5326, grad_fn=<MseLossBackward>)
# tensor(67.4341, grad_fn=<MseLossBackward>)
# tensor(67.3370, grad_fn=<MseLossBackward>)
# tensor(67.2412, grad_fn=<MseLossBackward>)
# tensor(67.1467, grad_fn=<MseLossBackward>)
# tensor(67.0534, grad_fn=<MseLossBackward>)
# tensor(66.9612, grad_fn=<MseLossBackward>)
# tensor(66.8706, grad_fn=<MseLossBackward>)
# tensor(66.7811, grad_fn=<MseLossBackward>)
# tensor(66.6928, grad_fn=<MseLossBackward>)
# tensor(66.6056, grad_fn=<MseLossBackward>)
# tensor(66.5196, grad_fn=<MseLossBackward>)
# tensor(66.4347, grad_fn=<MseLossBackward>)
# tensor(66.3504, grad_fn=<MseLossBackward>)
# tensor(66.2638, grad_fn=<MseLossBackward>)
# tensor(66.1783, grad_fn=<MseLossBackward>)
# tensor(66.0938, grad_fn=<MseLossBackward>)
# tensor(66.0113, grad_fn=<MseLossBackward>)
# tensor(65.9301, grad_fn=<MseLossBackward>)
# tensor(65.8506, grad_fn=<MseLossBackward>)
# tensor(65.7729, grad_fn=<MseLossBackward>)
# tensor(65.6975, grad_fn=<MseLossBackward>)
# tensor(65.6246, grad_fn=<MseLossBackward>)
# tensor(65.5558, grad_fn=<MseLossBackward>)
# tensor(65.4908, grad_fn=<MseLossBackward>)
# tensor(65.4336, grad_fn=<MseLossBackward>)
# tensor(65.3830, grad_fn=<MseLossBackward>)
# tensor(65.3483, grad_fn=<MseLossBackward>)
# Final Error: 65.324814324883

# %%
# Replotting the sample with y_true and y_pred
plot_3d(2, 'Y1 with RELU function Applied', X, y_true[:,0], y_pred[:,0])
plot_3d(2, 'Y2 with RELU function Applied', X, y_true[:,1], y_pred[:,1])
